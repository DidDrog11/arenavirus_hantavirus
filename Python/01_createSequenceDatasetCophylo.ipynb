# %%
import pandas as pd
import Bio
from Bio import SeqIO
from Bio import Entrez

# %%
#Species list
hanta_species = pd.read_csv('../data/ncbi_virus/associatedViralSpecies_cophylo.txt', sep='\t', header=None)
#rename the column
hanta_species.columns = ['species']

#Arha data
arha = pd.read_csv('../data/ncbi_virus/hantaviridae_ncbi_03062025.csv')
arha.columns = arha.columns.str.lower()
#Keep the L segment only
L_data = arha[arha['genbank_title'].str.contains(r"polymerase|segment L|L segment|Large", case=False, na=False)]
M_data = arha[arha['genbank_title'].str.contains(r"glycoprotein|segment M|M segment|Medium|medium|G1|G2", case=False, na=False)]
S_data = arha[arha['genbank_title'].str.contains(r"Nucleoprotein|nucleprotein|nucleocapsid|Nucleocapsid|segment S|S segment|Small|small", case=False, na=False)]
#Filter L and M from S data
S_data = S_data[S_data['segment'] != 'L']
S_data = S_data[S_data['segment'] != 'M']

#Group the arha data based on the species and find the most complete sequence

def select_longest_sequence(df, species_col="species", length_col="length", min_length=200, max_length=8000):
    # Convert the length column to numeric and drop rows with missing species or length values
    df[length_col] = pd.to_numeric(df[length_col], errors='coerce')
    df = df.dropna(subset=[species_col, length_col])
    
    def get_best_sequence(group):
        # Filter for sequences within the desired length range
        in_range = group[(group[length_col] >= min_length) & (group[length_col] <= max_length)]
        if not in_range.empty:
            # If sequences within the range exist, return the one with the maximum length
            return in_range.loc[in_range[length_col].idxmax()]
        else:
            # Otherwise, return the sequence with the maximum length overall (if available)
            if group[length_col].notna().any():
                return group.loc[group[length_col].idxmax()]
            else:
                return None

    result = df.groupby(species_col, group_keys=False).apply(get_best_sequence)
    result = result.dropna(subset=[length_col])
    return result

compare_datasets = [L_data, M_data, S_data]
for dataset in compare_datasets:
    selected_sequences = select_longest_sequence(dataset)
    print(len(selected_sequences[selected_sequences['species'].isin(hanta_species['species'])]))

#Since S segment has the most diversity, we'll use it

selected_sequences = select_longest_sequence(S_data)
selected_sequences = selected_sequences[selected_sequences['species'].isin(hanta_species['species'])]
accession_numbers = selected_sequences['accession'].tolist()

#Download the sequences
Entrez.email = "ricardo.rivero@wsu.edu"
handle = Entrez.efetch(db="nucleotide", id=accession_numbers, rettype="fasta", retmode="text")
records = SeqIO.parse(handle, "fasta")

#write the sequences to a file
with open('../data/ncbi_virus/hanta_S.fasta', 'w') as f:
    SeqIO.write(records, f, "fasta")

selected_sequences
# Out:
# /var/folders/8v/6y3r5h_x0dv5t5875drggrtc0000gn/T/ipykernel_43714/1043120449.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[length_col] = pd.to_numeric(df[length_col], errors='coerce')
# /var/folders/8v/6y3r5h_x0dv5t5875drggrtc0000gn/T/ipykernel_43714/1043120449.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[length_col] = pd.to_numeric(df[length_col], errors='coerce')
# 57
# 61
# 70
#        accession                  organism_name genbank_refseq  \
# 2      NC_077668    Orthohantavirus puumalaense         RefSeq
# 3      NC_077669  Orthohantavirus sinnombreense         RefSeq
# 8      NC_078263                 Xuan son virus         RefSeq
# 9      NC_078483                     Lena virus         RefSeq
# 18     NC_055375                     Brno virus         RefSeq
# ...          ...                            ...            ...
# 15335     M34881              Sapporo rat virus        GenBank
# 15339     M14626     Orthohantavirus hantanense        GenBank
# 15345     L08804    Orthohantavirus puumalaense        GenBank
# 15347     L11347    Orthohantavirus puumalaense        GenBank
# 15357     X61035    Orthohantavirus puumalaense        GenBank
#
#                                            assembly sra_accession  \
# 2                                   GCF_002829765.1           NaN
# 3                                   GCF_002830985.1           NaN
# 8                                   GCF_018594905.1           NaN
# 9                                   GCF_018596435.1           NaN
# 18                                  GCF_013086645.1           NaN
# ...                                             ...           ...
# 15335                                    set:M34881           NaN
# 15339                                    set:M14626           NaN
# 15345  set:503a14cd9dd548e3916edc83af80d5a439809964           NaN
# 15347                                    set:L11347           NaN
# 15357  set:e27da13161ba82fe5eb975bce7606284aee07c36           NaN
#
#                                               submitters  \
# 2      Stohwasser,R., Giebel,L.B., Zoller,L., Bautz,E...
# 3      Chizhikov,V.E., Spiropoulou,C.F., Morzunov,S.P...
# 8                                                    NaN
# 9      Yashina,L.N., Kartashov,M.Y., Wang,W., Li,K., ...
# 18     Strakova,P., Dufkova,L., Sirmarova,J., Salat,J...
# ...                                                  ...
# 15335  Arikawa,J., Lapenotiere,H.F., Iacono-Connors,L...
# 15339  Schmaljohn,C.S., Jennings,G.B., Hay,J., Dalrym...
# 15345       Xiao,S.Y., Spik,K.W., Li,D., Schmaljohn,C.S.
# 15347       Xiao,S.Y., Spik,K.W., Li,D., Schmaljohn,C.S.
# 15357  Vapalahti,O., Kallio-Kokko,H., Salonen,E.M., B...
#
#                                             organization org_location  \
# 2      National Center for Biotechnology Information,...          USA
# 3      National Center for Biotechnology Information,...          USA
# 8      National Center for Biotechnology Information,...          USA
# 9      National Center for Biotechnology Information,...          USA
# 18     National Center for Biotechnology Information,...          USA
# ...                                                  ...          ...
# 15335                                                NaN          NaN
# 15339                                                NaN          NaN
# 15345                                                NaN          NaN
# 15347                                                NaN          NaN
# 15357  O.P. Vapalahti, Dept. of Virology, University ...      Finland
#
#       release_date isolate  ... publications  \
# 2       2023-05-06     NaN  ...          1.0
# 3       2023-05-06  NM R11  ...          1.0
# 8       2023-05-06    PR15  ...          NaN
# 9       2023-05-06     NaN  ...          1.0
# 18      2021-06-01     NaN  ...          1.0
# ...            ...     ...  ...          ...
# 15335   1993-08-03     NaN  ...          1.0
# 15339   1993-08-02     NaN  ...          1.0
# 15345   1993-07-26     NaN  ...          1.0
# 15347   1993-06-12     NaN  ...          1.0
# 15357   1991-08-02     NaN  ...          1.0
#
#                             geo_location         country  usa  \
# 2                                    NaN             NaN  NaN
# 3                                    NaN             NaN  NaN
# 8      China: Yunnan province, Puer city           China  NaN
# 9                Russia: Khabarovsk Krai          Russia  NaN
# 18                        Czech Republic  Czech Republic  NaN
# ...                                  ...             ...  ...
# 15335                                NaN             NaN  NaN
# 15339                                NaN             NaN  NaN
# 15345                                NaN             NaN  NaN
# 15347                                NaN             NaN  NaN
# 15357                                NaN             NaN  NaN
#
#                          host tissue_specimen_source collection_date  \
# 2                         NaN                    NaN             NaN
# 3      Peromyscus maniculatus                    NaN             NaN
# 8         Hipposideros pomona                   lung            2013
# 9            Sorex caecutiens                   lung         2008-02
# 18           Nyctalus noctula                  liver            2012
# ...                       ...                    ...             ...
# 15335                     NaN                    NaN             NaN
# 15339                     NaN                    NaN             NaN
# 15345                     NaN                    NaN             NaN
# 15347                     NaN                    NaN             NaN
# 15357                     NaN                    NaN             NaN
#
#       biosample   bioproject  \
# 2           NaN  PRJNA485481
# 3           NaN  PRJNA485481
# 8           NaN  PRJNA485481
# 9           NaN  PRJNA485481
# 18          NaN  PRJNA485481
# ...         ...          ...
# 15335       NaN          NaN
# 15339       NaN          NaN
# 15345       NaN          NaN
# 15347       NaN          NaN
# 15357       NaN          NaN
#
#                                            genbank_title
# 2      Puumala virus CG1820 segment S nucleocapsid pr...
# 3      Sin Nombre virus (NM R11) RNA S segment encodi...
# 8      Xuan son virus isolate PR15 segment S, complet...
# 9      Lena River virus strain Khekhtsir-Sc67/Russia/...
# 18     Brno virus strain 7/2012/CZE nucleocapsid prot...
# ...                                                  ...
# 15335  Sapporo rat virus mRNA S segment, encoding an ...
# 15339  Hantaan virus S segment encoding nucleocapsid ...
# 15345  Hantavirus Puumala nucleocapsid protein, compl...
# 15347  Hantavirus Puumala P360 nucleocapsid protein m...
# 15357  Puumala virus genomic RNA for nucleocapsid pro...
#
# [6241 rows x 28 columns]

# %%
#Align using mafft
import subprocess
subprocess.run(["mafft", "--genafpair", "--maxiterate 16", "-reorder","../data/ncbi_virus/hanta_S.fasta", ">", "../data/ncbi_virus/hanta_S_aligned.fasta"], shell=True)
# Out:
# awk: cmd. line:11: fatal: cannot redirect to `/dev/tty': Device not configured
# CompletedProcess(args=['mafft', '--auto', '../data/ncbi_virus/hanta_S.fasta', '>', '../data/ncbi_virus/hanta_S_aligned.fasta'], returncode=0)
